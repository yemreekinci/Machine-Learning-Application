# %%
import pandas as pd
df = pd.read_parquet("data.parquet")
display(df.head(100))
# Out:
#             Brand    Model Power     Date   Mileage Transmission      Fuel  \
# 0           Skoda  Octavia    81   1/2016              Automatic    Petrol
# 1            Fiat   Ducato   103   7/2021   90000km       Manual    Diesel
# 2   Mercedes-Benz     Vito   120   3/2021  170000km    Automatic    Diesel
# 3       Chevrolet    Spark    50   2/2012  161000km       Manual    Petrol
# 4          Nissan    Micra    59   6/2014  162000km       Manual    Petrol
# ..            ...      ...   ...      ...       ...          ...       ...
# 95           Fiat  Talento   107   9/2020  114159km       Manual    Diesel
# 96          Mazda    MX-30   105  11/2020  105261km    Automatic    Hybrid
# 97         Nissan     Leaf   110   9/2023    1697km    Automatic  Electric
# 98          Isuzu    D-Max   120   6/2023   20000km    Automatic    Diesel
# 99  Mercedes-Benz     Vito   120   6/2021   99218km    Automatic    Diesel
#
#    Drive Type  Price
# 0              11199
# 1              22749
# ...

# %%
df.shape
# Out:
# (1078436, 9)
